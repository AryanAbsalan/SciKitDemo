# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("darkgrid") 

"""
Also known as "Census Income" dataset.
age: continuous.
workclass: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.
fnlwgt: continuous.
education: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.
education-num: continuous.
marital-status: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.
occupation: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.
relationship: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.
race: White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black.
sex: Female, Male.
capital-gain: continuous.
capital-loss: continuous.
hours-per-week: continuous.
native-country: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands
income:Predict whether income exceeds $50K/yr based on census data. 

"""
data = pd.read_csv("adult.data")
data
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
plt.figure(figsize=(15, 15), dpi=80)
sns.countplot(y=data["age"])
plt.show()

# %%
# ['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#  'marital-status', 'occupation', 'relationship', 'race', 'sex',
#  'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#  'income']
plt.figure(figsize=(15, 15), dpi=80)
sns.countplot(y=data["workclass"])
plt.show()

# %%
plt.figure(figsize=(15, 15), dpi=80)
sns.countplot(y=data["education"])
plt.show()

# %%
plt.figure(figsize=(15, 15), dpi=80)
sns.countplot(y=data["education-num"])
plt.show()

# %%
plt.figure(figsize=(15, 15), dpi=80)
sns.countplot(y=data["marital-status"])
plt.show()

# %%
plt.figure(figsize=(15, 15), dpi=80)
sns.countplot(y=data["occupation"])
plt.show()

# %%
plt.figure(figsize=(15, 15), dpi=80)
sns.countplot(y=data["relationship"])
plt.show()

# %%
plt.figure(figsize=(15, 15), dpi=80)
sns.countplot(y=data["race"])
plt.show()

# %%
plt.figure(figsize=(15, 15), dpi=80)
sns.countplot(y=data["sex"])
plt.show()

# %%
plt.figure(figsize=(15, 15), dpi=80)
sns.countplot(y=data["capital-gain"])
plt.show()

# %%
plt.figure(figsize=(15, 15), dpi=80)
sns.countplot(y=data["workclass"])
sns.countplot(y=data["capital-loss"])
plt.show()

# %%
plt.figure(figsize=(15, 15), dpi=80)
sns.countplot(y=data["hours-per-week"])
plt.show()

# %%
plt.figure(figsize=(15, 15), dpi=80)
sns.countplot(y=data["native-country"])
plt.show()

# %%
plt.figure(figsize=(15, 15), dpi=80)
sns.countplot(y=data["income "])
plt.show()

# %%
labels = list(data["native-country"].value_counts().index)
labels
# Out:
# [' United-States',
#  ' Mexico',
#  ' ?',
#  ' Philippines',
#  ' Germany',
#  ' Canada',
#  ' Puerto-Rico',
#  ' El-Salvador',
#  ' India',
#  ' Cuba',
#  ' England',
#  ' Jamaica',
#  ' South',
#  ' China',
#  ' Italy',
#  ' Dominican-Republic',
#  ' Vietnam',
#  ' Guatemala',
#  ' Japan',
#  ' Poland',
#  ' Columbia',
#  ' Taiwan',
#  ' Haiti',
#  ' Iran',
#  ' Portugal',
#  ' Nicaragua',
#  ' Peru',
#  ' France',
#  ' Greece',
#  ' Ecuador',
#  ' Ireland',
#  ' Hong',
#  ' Cambodia',
#  ' Trinadad&Tobago',
#  ' Laos',
#  ' Thailand',
#  ' Yugoslavia',
#  ' Outlying-US(Guam-USVI-etc)',
#  ' Honduras',
#  ' Hungary',
#  ' Scotland',
#  ' Holand-Netherlands']

# %%
# ['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#  'marital-status', 'occupation', 'relationship', 'race', 'sex',
#  'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#  'income ']
plt.figure(figsize=(16, 16), dpi=80)
plt.pie(data["native-country"].value_counts(), autopct='%.1f%%', labels=labels)
plt.title("Distribution of native-country")
plt.show()

# %%
labels = list(data["education"].value_counts().index)
# ['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#  'marital-status', 'occupation', 'relationship', 'race', 'sex',
#  'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#  'income ']
plt.figure(figsize=(16, 16), dpi=80)
plt.pie(data["education"].value_counts(), autopct='%.1f%%', labels=labels)
plt.title("Distribution of education")
plt.show()

# %%
labels = list(data["marital-status"].value_counts().index)
# ['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#  'marital-status', 'occupation', 'relationship', 'race', 'sex',
#  'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#  'income ']
plt.figure(figsize=(16, 16), dpi=80)
plt.pie(data["marital-status"].value_counts(), autopct='%.1f%%', labels=labels)
plt.title("Distribution of marital-status")
plt.show()

# %%
labels = list(data["occupation"].value_counts().index)
# ['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#  'marital-status', 'occupation', 'relationship', 'race', 'sex',
#  'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#  'income ']
plt.figure(figsize=(16, 16), dpi=80)
plt.pie(data["occupation"].value_counts(), autopct='%.1f%%', labels=labels)
plt.title("Distribution of occupation")
plt.show()

# %%
labels = list(data["relationship"].value_counts().index)
# ['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#  'marital-status', 'occupation', 'relationship', 'race', 'sex',
#  'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#  'income ']
plt.figure(figsize=(16, 16), dpi=80)
plt.pie(data["relationship"].value_counts(), autopct='%.1f%%', labels=labels)
plt.title("Distribution of relationship")
plt.show()

# %%
labels = list(data["sex"].value_counts().index)
# ['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#  'marital-status', 'occupation', 'relationship', 'race', 'sex',
#  'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#  'income ']
plt.figure(figsize=(16, 16), dpi=80)
plt.pie(data["sex"].value_counts(), autopct='%.1f%%', labels=labels)
plt.title("Distribution of sex")
plt.show()
