# %%
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("darkgrid")

# Load the Iris dataset
iris = load_iris()

# Convert the data to a Pandas DataFrame
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
df['target'] = iris.target
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
df.count()
# Out:
# sepal length (cm)    150
# sepal width (cm)     150
# petal length (cm)    150
# petal width (cm)     150
# target               150
# dtype: int64

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)      target
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %%
df.isnull().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# dtype: int64

# %%
df["target"].value_counts()
# Out:
# 0    50
# 1    50
# 2    50
# Name: target, dtype: int64

# %%
plt.figure(figsize=(10, 6), dpi=80)
sns.countplot(y=df["target"])
plt.show()

# %%
df.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'target'],
#       dtype='object')

# %%
fig, axes = plt.subplots(figsize=(20, 10), nrows=3, ncols=4)

# Define the colors for each column
colors = ['blue', 'orange', 'green', 'red']

# Iterate over the columns and plot the histograms, KDEs, and boxplots
col_no = 0
for col in df.columns[:-1]:
    sns.histplot(x=col, data=df, ax=axes[0, col_no], bins=20, color=colors[col_no])
    sns.kdeplot(x=col, data=df, ax=axes[1, col_no], color=colors[col_no])
    sns.boxplot(x=col, data=df, ax=axes[2, col_no], color=colors[col_no])
    col_no += 1

plt.tight_layout()
plt.show()

# %%
labels = list(df["target"].value_counts().index)

plt.figure(figsize=(6, 8), dpi=80)
plt.pie(df["target"].value_counts(), autopct='%.2f%%', labels=labels)
plt.title("Distribution")
plt.show()

# %%
plt.figure(figsize=(8, 6), dpi=80)
sns.heatmap(df.corr(), annot=True)
plt.show()
